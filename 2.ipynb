# %%
import pandas as pd
df =pd.read_csv("SuperMarket.csv")
df.shape
# Out:
# (1014, 17)

# %%
##1014 Rows 17 Coloumns
print(df.shape)
# Out:
# (1014, 17)

# %%
df.isnull().sum()
# Out:
# Invoice ID                  0
# Branch                      0
# City                        0
#    Customer type            0
# Gender                      0
# Product line                0
# Unit price                 24
# Quantity                    0
# Tax 5%                      0
# Sales                      20
# Date                       12
# Time                        0
# Payment                     0
#    cogs                     0
# gross margin percentage     0
# gross income                0
# Rating                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(14)

# %%
df.describe()
# Out:
#        Unit price     Quantity       Tax 5%         cogs  \
# count  990.000000  1014.000000  1014.000000  1014.000000
# mean    55.520333     5.502959    15.336872   306.737436
# std     26.330508     2.927133    11.685945   233.718896
# min     10.080000     1.000000     0.508500    10.170000
# 25%     33.202500     3.000000     5.864625   117.292500
# 50%     54.890000     5.000000    12.066000   241.320000
# 75%     77.667500     8.000000    22.428000   448.560000
# max     99.960000    10.000000    49.650000   993.000000
#
#        gross margin percentage  gross income       Rating
# count              1014.000000   1014.000000  1014.000000
# mean                  4.761905     15.336872     6.960454
# std                   0.000000     11.685945     1.721264
# min                   4.761905      0.508500     4.000000
# 25%                   4.761905      5.864625     5.500000
# 50%                   4.761905     12.066000     6.900000
# ...
